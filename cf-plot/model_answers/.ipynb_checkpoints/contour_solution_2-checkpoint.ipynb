# %% [markdown]
# # Contour plotting exercise 2
#
# # Make a Quasi Biennial-Oscillation (QBO) plot¶

# %%
# Inline images in Ipython Notebook - not needed in Python
# %matplotlib inline

# %%
# Import the cf-python and cf-plot packages

import cf
import cfplot as cfp

# %%
# Read in a file called ncas_data/qbo.nc

f=cf.read_field('ncas_data/qbo.nc')

# %%
# See what is in the file

print f
# Out:
# Field: eastward_wind (ncvar%U)
# ------------------------------
# Data           : eastward_wind(time(398), pressure(37), latitude(37), longitude(48)) m s**-1
# Axes           : time(398) = [1979-01-16T09:00:00Z, ..., 2012-02-15T09:00:00Z] gregorian
#                : pressure(37) = [1000.0, ..., 1.0] mbar
#                : latitude(37) = [90.0, ..., -90.0] degrees_north
#                : longitude(48) = [0.0, ..., 352.5] degrees_east

# %%
# Make a zonal mean of the data using the cf-python collapse method

g=f.collapse('mean', 'X')

# %%
# Select the data at the equator with the cf-python subspace method

h=g.subspace(Y=0.0)

# %%
# Make a contour plot of the data with a log y-axis

cfp.con(h, ylog=True)
# Out:
# /usr/local/anaconda2/lib/python2.7/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'tri'
#   s)

# %%
# Use cfp.gset in cf-plot to select the plotting region time: 1980 to 2000, pressure 1000mb to 1mb
# Hint - use time notation 'YYYY-MM-DD' 

cfp.gset(xmin='1980-1-1', xmax='2000-1-1', ymin=1000, ymax=1)

# %%
# Remake the plot this time turning off the plotting of the contour lines
# If you don't know how to do this run the command help(cfp.con) to find out the sytax required.

# %%
help(cfp.con)
# Out:
# Help on function con in module cfplot.cfplot:
#
# con(f=None, x=None, y=None, fill=True, lines=True, line_labels=True, title=None, colorbar_title=None, colorbar=True, colorbar_label_skip=None, ptype=0, negative_linestyle='solid', blockfill=False, zero_thick=False, colorbar_shrink=None, colorbar_orientation=None, colorbar_position=None, xlog=False, ylog=False, axes=True, xaxis=True, yaxis=True, xticks=None, xticklabels=None, yticks=None, yticklabels=None, xlabel=None, ylabel=None, colors='k', swap_axes=False, verbose=None, linewidths=None, alpha=1.0, colorbar_text_up_down=False, colorbar_text_down_up=False, colorbar_drawedges=True, linestyles=None)
#     | con is the interface to contouring in cf-plot. The minimum use is con(f)
#     | where f is a 2 dimensional array. If a cf field is passed then an
#     | appropriate plot will be produced i.e. a longitude-latitude or
#     | latitude-height plot for example. If a 2d numeric array is passed then
# ...

# %%
cfp.con(h, ylog=True, lines=False)
